# %% [markdown]
# **import required packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Read the data**

# %%
visa_df = pd.read_csv(r'C:\Users\ankus\Documents\Naresh IT Ankush\Datasets\Visadataset - Visadataset.csv')
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# $head$
#
# - Top 5 rows

# %%
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %% [markdown]
# $tail$
#
# - Last 5 rows

# %%
visa_df.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
visa_df.head(10)
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 0  EZYV01           Asia           High School                  N
# 1  EZYV02           Asia              Master's                  Y
# 2  EZYV03           Asia            Bachelor's                  N
# 3  EZYV04           Asia            Bachelor's                  N
# 4  EZYV05         Africa              Master's                  Y
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
# 8  EZYV09           Asia            Bachelor's                  N
# 9  EZYV10         Europe             Doctorate                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# ...

# %%
visa_df.tail(10)
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 25470  EZYV25471  North America              Master's                  Y
# 25471  EZYV25472           Asia           High School                  N
# 25472  EZYV25473           Asia           High School                  N
# 25473  EZYV25474           Asia            Bachelor's                  Y
# 25474  EZYV25475         Africa             Doctorate                  N
# 25475  EZYV25476           Asia            Bachelor's                  Y
# 25476  EZYV25477           Asia           High School                  Y
# 25477  EZYV25478           Asia              Master's                  Y
# 25478  EZYV25479           Asia              Master's                  Y
# 25479  EZYV25480           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25470                     N             2272         1970
# ...

# %%
visa_df.head(100)
# Out:
#     case_id      continent education_of_employee has_job_experience  \
# 0    EZYV01           Asia           High School                  N
# 1    EZYV02           Asia              Master's                  Y
# 2    EZYV03           Asia            Bachelor's                  N
# 3    EZYV04           Asia            Bachelor's                  N
# 4    EZYV05         Africa              Master's                  Y
# ..      ...            ...                   ...                ...
# 95   EZYV96           Asia              Master's                  N
# 96   EZYV97  North America            Bachelor's                  Y
# 97   EZYV98  North America            Bachelor's                  Y
# 98   EZYV99           Asia           High School                  N
# 99  EZYV100           Asia              Master's                  N
#
#    requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# ...

# %% [markdown]
# $shape$

# %%
visa_df.shape
# Out:
# (25480, 12)

# %%
#(rows,columns)

# %%
print(f"The number of rows are {visa_df.shape[0]}")
print(f"The number of columns are {visa_df.shape[1]}")
# Out:
# The number of rows are 25480
# The number of columns are 12

# %% [markdown]
# $size$
#
# - Number of records/cells/fields/values/rowsxcolumns

# %%
visa_df.size
# Out:
# 305760

# %% [markdown]
# $columns$

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# ## $dtypes$

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %% [markdown]
# - Understanding data types is very important
#
# - visa_df is : **dataFrame**
#
# - visa_df.values is : **series**
#
# - Series objects can convert into dictionary
#
# - After that we can use dictionary methods

# %%
type(visa_df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(visa_df.values)
# Out:
# numpy.ndarray

# %%
type(visa_df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# **task**
#
# - Create categorical list
#
# - Create numerical column list
#
# **idea**
#
# - Convert series type into dictionary
#
# - Iterate through loop
#
# - Apply the condition get the result in the list

# %%
dictt = dict(visa_df.dtypes)
dictt
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
cat_cols = [key for key,value in dtypes.items() if value=='object']
num_cols = [key for key,value in dtypes.items() if value!='object']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 cat_cols = [key for key,value in dtypes.items() if value=='object']
#       2 num_cols = [key for key,value in dtypes.items() if value!='object']
#
# NameError: name 'dtypes' is not defined

# %% [markdown]
# $select$-$data$-$types$
#
# - Select data types will give a data frame of desired data types
#
# - The result also a data frame
#
# - All above options like head tail

# %%
visa_df.select_dtypes(include='object')
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training region_of_employment unit_of_wage  \
# 0                         N                 West         Hour
# ...

# %%
visa_df.select_dtypes(include='int')
# Out:
#        no_of_employees  yr_of_estab
# 0                14513         2007
# 1                 2412         2002
# 2                44444         2008
# 3                   98         1897
# 4                 1082         2005
# ...                ...          ...
# 25475             2601         2008
# 25476             3274         2006
# 25477             1121         1910
# 25478             1918         1887
# 25479             3195         1960
#
# [25480 rows x 2 columns]

# %%
import pandas as pd

# Sample DataFrame
visa_df = pd.read_csv(r'C:\Users\ankus\Documents\Naresh IT Ankush\Datasets\Visadataset - Visadataset.csv')


# Step 1: Convert series types to dictionary
dtype_dict = visa_df.dtypes.to_dict()

# Initialize lists for categorical and numerical columns
categorical_columns = []
numerical_columns = []

# Step 2: Iterate through the dictionary and apply conditions
for column, dtype in dtype_dict.items():
    if pd.api.types.is_numeric_dtype(dtype):
        numerical_columns.append(column)
    else:
        categorical_columns.append(column)

# Output the results
print("Categorical Columns:", categorical_columns)
print("Numerical Columns:", numerical_columns)
# Out:
# Categorical Columns: ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
# Numerical Columns: ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
import pandas as pd

# Sample DataFrame
visa_df = pd.read_csv(r'C:\Users\ankus\Documents\Naresh IT Ankush\Datasets\Visadataset - Visadataset.csv')

# Step 1: Convert series types to dictionary
dtype_dict = visa_df.dtypes.to_dict()

# Initialize lists for categorical and numerical columns
categorical_columns = []
numerical_columns = []

# Step 2: Iterate through the dictionary and apply conditions
for column, dtype in dtype_dict.items():
    if pd.api.types.is_numeric_dtype(dtype):
        numerical_columns.append(column)
    else:
        categorical_columns.append(column)

# Create separate DataFrames
categorical_df = visa_df[categorical_columns]
numerical_df = visa_df[numerical_columns]

# Output the results
print("Categorical Columns:", categorical_columns)
print("Numerical Columns:", numerical_columns)

# Display DataFrames

categorical_df,numerical_df
# Out:
# Categorical Columns: ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
# Numerical Columns: ['no_of_employees', 'yr_of_estab', 'prevailing_wage']
# (         case_id continent education_of_employee has_job_experience  \
#  0         EZYV01      Asia           High School                  N
#  1         EZYV02      Asia              Master's                  Y
#  2         EZYV03      Asia            Bachelor's                  N
#  3         EZYV04      Asia            Bachelor's                  N
#  4         EZYV05    Africa              Master's                  Y
#  ...          ...       ...                   ...                ...
#  25475  EZYV25476      Asia            Bachelor's                  Y
#  25476  EZYV25477      Asia           High School                  Y
#  25477  EZYV25478      Asia              Master's                  Y
# ...

# %%
visa_df.select_dtypes(exclude='object')
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage
# 0                14513         2007         592.2029
# 1                 2412         2002       83425.6500
# 2                44444         2008      122996.8600
# 3                   98         1897       83434.0300
# 4                 1082         2005      149907.3900
# ...                ...          ...              ...
# 25475             2601         2008       77092.5700
# 25476             3274         2006      279174.7900
# 25477             1121         1910      146298.8500
# 25478             1918         1887       86154.7700
# 25479             3195         1960       70876.9100
#
# [25480 rows x 3 columns]

# %% [markdown]
# $is$-$null$
#
# - is used to identify the any missing values are available
#
# - is null means we are asking a question to the computer
#
# - It will give True or False
#
# - True: yes value is missed
#
# - False: No value is not missed

# %%
visa_df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
# bound method means the method need parenthesis

# %%
visa_df.isna()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %% [markdown]
# $drop$-$duplicates$
#
# - if any duplicate rows are there we can drop it

# %%
visa_df.drop_duplicates()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.drop_duplicates().all()
# Out:
# case_id                  True
# continent                True
# education_of_employee    True
# has_job_experience       True
# requires_job_training    True
# no_of_employees          True
# yr_of_estab              True
# region_of_employment     True
# prevailing_wage          True
# unit_of_wage             True
# full_time_position       True
# case_status              True
# dtype: bool

# %% [markdown]
# $info$

# %%
visa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# $take$
#
# - used  to extract the perticular index of data
#
# - take has one parameter called axis
#
# - axis =1: columns
#
# - axis=0 : rows
#
# - axis = 0 is default
#
# - in below example we have given 100,200,300 and we did not provided axis value so axis = 0 is default

# %%
visa_df.take([100,200,300])
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.take([10:21])
# Out:
#   Cell In[41], line 1
#     visa_df.take([10:21])
#                     ^
# SyntaxError: invalid syntax

# %%
visa_df.take([4,7,9],axis=1)
# Out:
#       requires_job_training region_of_employment unit_of_wage
# 0                         N                 West         Hour
# 1                         N            Northeast         Year
# 2                         Y                 West         Year
# 3                         N                 West         Year
# 4                         N                South         Year
# ...                     ...                  ...          ...
# 25475                     Y                South         Year
# 25476                     N            Northeast         Year
# 25477                     N                South         Year
# 25478                     Y                 West         Year
# 25479                     N              Midwest         Year
#
# [25480 rows x 3 columns]

# %%
visa_df.take([100,200,300]).take([2,5,7],axis=1)
# Out:
#     education_of_employee  no_of_employees region_of_employment
# 100              Master's             2227            Northeast
# 200             Doctorate             3282                 West
# 300              Master's             3268              Midwest

# %% [markdown]
# ## **$iloc$**

# %%
# visa_df.iloc[<rows>,<columns>]
# here slicing is possible
# visa_df.iloc[<start:end+1>,<start:end+1>]
visa_df.iloc[100:110,2:6]
# Out:
#     education_of_employee has_job_experience requires_job_training  \
# 100              Master's                  Y                     N
# 101              Master's                  Y                     N
# 102            Bachelor's                  Y                     N
# 103             Doctorate                  Y                     N
# 104              Master's                  Y                     N
# 105             Doctorate                  Y                     N
# 106            Bachelor's                  N                     N
# 107            Bachelor's                  Y                     N
# 108            Bachelor's                  N                     N
# 109            Bachelor's                  Y                     N
#
#      no_of_employees
# 100             2227
# 101              334
# 102              224
# 103              367
# 104              306
# 105             2317
# 106              890
# 107             2002
# 108             2903
# ...

# %%
visa_df.iloc[[100,200,300],[2,5,7]]
# Out:
#     education_of_employee  no_of_employees region_of_employment
# 100              Master's             2227            Northeast
# 200             Doctorate             3282                 West
# 300              Master's             3268              Midwest

# %%
visa_df.iloc[[100],:]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified

# %%
visa_df.iloc[:,[7]]
# Out:
#       region_of_employment
# 0                     West
# 1                Northeast
# 2                     West
# 3                     West
# 4                    South
# ...                    ...
# 25475                South
# 25476            Northeast
# 25477                South
# 25478                 West
# 25479              Midwest
#
# [25480 rows x 1 columns]

# %%
visa_df.iloc[100,:]
# Out:
# case_id                    EZYV101
# continent                     Asia
# education_of_employee     Master's
# has_job_experience               Y
# requires_job_training            N
# no_of_employees               2227
# yr_of_estab                   2007
# region_of_employment     Northeast
# prevailing_wage           28243.79
# unit_of_wage                  Year
# full_time_position               Y
# case_status              Certified
# Name: 100, dtype: object

# %%
visa_df.iloc[100]
# Out:
# case_id                    EZYV101
# continent                     Asia
# education_of_employee     Master's
# has_job_experience               Y
# requires_job_training            N
# no_of_employees               2227
# yr_of_estab                   2007
# region_of_employment     Northeast
# prevailing_wage           28243.79
# unit_of_wage                  Year
# full_time_position               Y
# case_status              Certified
# Name: 100, dtype: object

# %% [markdown]
# **Note**
#
# - No bracket : series
#
# - bracket : dataframe

# %%
visa_df.iloc[100].to_dict()
# Out:
# {'case_id': 'EZYV101',
#  'continent': 'Asia',
#  'education_of_employee': "Master's",
#  'has_job_experience': 'Y',
#  'requires_job_training': 'N',
#  'no_of_employees': 2227,
#  'yr_of_estab': 2007,
#  'region_of_employment': 'Northeast',
#  'prevailing_wage': 28243.79,
#  'unit_of_wage': 'Year',
#  'full_time_position': 'Y',
#  'case_status': 'Certified'}

# %%
# no. of employees data

visa_df.iloc[:,[5]]
# Out:
#        no_of_employees
# 0                14513
# 1                 2412
# 2                44444
# 3                   98
# 4                 1082
# ...                ...
# 25475             2601
# 25476             3274
# 25477             1121
# 25478             1918
# 25479             3195
#
# [25480 rows x 1 columns]

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.columns.index('continent')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 visa_df.columns.index('continent')
#
# AttributeError: 'Index' object has no attribute 'index'

# %%
type(visa_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
cols=list(visa_df.columns)
cols
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'no_of_employees',
#  'yr_of_estab',
#  'region_of_employment',
#  'prevailing_wage',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
cols.index('no_of_employees')
# Out:
# 5

# %% [markdown]
# $loc$
#
# - loc will take directly column names

# %%
visa_df.loc[[100,200,300],['case_id']]
# Out:
#      case_id
# 100  EZYV101
# 200  EZYV201
# 300  EZYV301
